# %%
from FairallDataManager import FairallDataManager

# %%
# Initialise the data object
fairall_data = FairallDataManager("F9LCs.csv")

# %%
# Plot the light curve - example V-band
fairall_data.plot_light_curve("UVOT", "V")

# %%
# Use the class method to interpolate this data
fairall_data.interpolate_light_curve('UVOT', 'V')
# Out:
# C:\Users\aksha\Desktop\Coding\Dissertation\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8 ) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# Plot just the mean of the light curve of the samples
# Confidence interval aligns with data where there are datapoints and wide band shows in the gaps
fairall_data.interpolate_light_curve('UVOT', 'V', leave_out_data=True)
# Out:
# C:\Users\aksha\Desktop\Coding\Dissertation\.venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8 ) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
